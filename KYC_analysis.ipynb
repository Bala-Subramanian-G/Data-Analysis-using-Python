# %% [markdown]
# <a href="https://colab.research.google.com/github/Bala-Subramanian-G/Data-Analysis-using-Python/blob/main/KYC_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **KYC ANALYSIS** OF INTERNSHIP APPLICANTS.

# %% [markdown]
# This dataset has been created using the google form response of students who registered for an internship at [Senchola University](https://www.linkedin.com/company/senchola-university/).
#
# Since it is the real-time data i.e. data of actual people, it’s not acceptable to disclose their personal details. So, I just remove name and address columns and also, I shuffle the details of some other columns.

# %% [markdown]
# Note: Charts that are created with plotly library is not supported in Github version. So click the **'open-in-colab'** button and run this notebook in Google Colab to be able to see those outputs.
#
# Or, [click here](https://www.linkedin.com/posts/bala-subramanian-g_kyc-analysis-activity-7175733250131165185-aMJq?utm_source=share&utm_medium=member_desktop) to look at the pdf version where all charts are visible.
#
# --> If you are running this notebook file at your side, don't run some of the following cells. Directly go to '**Run the code Yourself**' cell and follow the instructions mentioned over there.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly import graph_objects as go

# %%
#Reading the dataset

df = pd.read_excel('/content/drive/MyDrive/Practice Datasets/Task-4 batch 1 application.xlsx')

# %%
# Checking the columns present in the dataset
df.columns
# Out:
# Index(['Date', 'Time', 'Open to learn?', 'Purpose of joining?', 'Have laptop?',
#        'Name', 'Gender', 'Address', 'Qualification', 'Degree', 'Branch', 'YOP',
#        'College Name', 'City', 'State', 'Domain', 'Comments',
#        'Confidence Rating', 'Status'],
#       dtype='object')

# %%
# Deleting Name, address and College Name Column as I found them sensitive informations

df.drop(['Name','Address','College Name',], axis=1,inplace=True)

# %%
# Shuffling the Gender Column
df['Gender'] = df['Gender'].sample(frac=1).reset_index(drop=True)

# Shuffling the Qualification, Degree and Branch Column together
df[['Qualification', 'Degree', 'Branch']] = df[['Qualification', 'Degree', 'Branch']].sample(frac=1).reset_index(drop=True)

# %%
df.head(4)
# Out:
#         Date      Time Open to learn?  \
# 0 2023-04-04  06:48:39            Yes
# 1 2023-04-05  11:24:40            Yes
# 2 2023-04-04  10:41:49          Maybe
# 3 2023-04-04  09:16:33            Yes
#
#                                  Purpose of joining? Have laptop? Gender  \
# 0                               To upgrade my skills          Yes   Male
# 1      I need to learn more skills about technology           Yes   Male
# 2  I have internship in the month of April to Jun...          Yes   Male
# 3  I am persuing my MSW in Hr. An additional inte...          Yes   Male
#
#     Qualification  Degree                  Branch   YOP         City  \
# 0     Engineering  B.Tech        Data Not Entered  2021   Perambalur
# 1  Arts & Science    B.Sc        Data Not Entered  2023  Tirunelveli
# 2     Engineering     B.E  Mechanical Engineering  2023     Namakkal
# 3  Arts & Science     MSW   Master Of Social Work  2023      Chennai
#
#        State                  Domain  \
# 0  Tamilnadu            UI/UX Design
# 1  Tamilnadu  Full Stack Development
# 2  Tamilnadu                HR/Admin
# 3  Tamilnadu                HR/Admin
#
#                                             Comments Confidence Rating  \
# 0  She doing course in chennai for QA. She lookin...                 6
# 1                                   Data Not Entered  Data Not Entered
# 2                                   Data Not Entered  Data Not Entered
# 3  did english litrature. did intership. english ...                 9
#
#              Status
# 0        Next Batch
# 1  Data Not Entered
# 2  Data Not Entered
# 3        We can try

# %%
# Removing some unwanted columns which are irrelevant to KYC Analysis

df.drop(['Purpose of joining?','Comments'], axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date      Time Open to learn? Have laptop? Gender   Qualification  \
# 0 2023-04-04  06:48:39            Yes          Yes   Male     Engineering
# 1 2023-04-05  11:24:40            Yes          Yes   Male  Arts & Science
# 2 2023-04-04  10:41:49          Maybe          Yes   Male     Engineering
# 3 2023-04-04  09:16:33            Yes          Yes   Male  Arts & Science
# 4 2023-04-19  11:36:46            Yes          Yes   Male  Arts & Science
#
#    Degree                             Branch   YOP         City      State  \
# 0  B.Tech                   Data Not Entered  2021   Perambalur  Tamilnadu
# 1    B.Sc                   Data Not Entered  2023  Tirunelveli  Tamilnadu
# 2     B.E             Mechanical Engineering  2023     Namakkal  Tamilnadu
# 3     MSW              Master Of Social Work  2023      Chennai  Tamilnadu
# 4     MBA  Master Of Business Administration  2021        Hosur  Tamilnadu
#
#                    Domain Confidence Rating            Status
# 0            UI/UX Design                 6        Next Batch
# 1  Full Stack Development  Data Not Entered  Data Not Entered
# 2                HR/Admin  Data Not Entered  Data Not Entered
# 3                HR/Admin                 9        We can try
# 4  Full Stack Development  Data Not Entered  Data Not Entered

# %%
# I am exporting the dataset for your reference, after performing alterations in the dataset.
df.to_excel('KYC Dataset.xlsx')

# %% [markdown]
# [Click here](https://docs.google.com/spreadsheets/d/1uTrW6vgudnxs35iz_xKcBHBJFgDW4RpS/edit?usp=sharing&ouid=106167233124360229976&rtpof=true&sd=true) to download the dataset.

# %% [markdown]
# **RUN THE CODE YOURSELF**

# %%
'''
Download the dataset. Upload that file in google drive. Copy the file path and
paste it in below code's address box.

NO NEED TO RUN ABOVE CELLS. RUN the current cell and all upcoming cells.
'''
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly import graph_objects as go
# df = pd.read_excel(< paste the file address here and run this line >)
df.head()

# %%
plt.figure(figsize=(4,5))
x=sns.countplot(df,x='Gender')
for i in x.containers:
  x.bar_label(i)
plt.title("Gender count")
plt.show()

# %%
x=df['Domain'].value_counts()
my_explode=[0,0,0,0,0,0,0.1,.15,.2,.3,.4,.5]
plt.figure(figsize=(7,7))
plt.pie(x, labels=x.values, autopct='%0.1f%%', explode= my_explode,
        colors= ['#87CEEB','#EDB1B1','#E74C3C', '#3498DB','#2ECC71','#CACACA'
        ,'#F1C40F','#FF8181','orange','#1ABC9C','#ECECEC','yellow'])
plt.legend(x.index, loc='upper left', bbox_to_anchor=(1, 1.02))
plt.title('DOMAIN ')
plt.show()

# %%
x=df['Qualification'].value_counts()
plt.pie(x, labels=x.values, autopct='%0.1f%%',
        colors=['#90EE90','#87CEEB','#EDB1B1'],
        pctdistance=0.80, explode=[.015,.015,.015])

centre_circle = plt.Circle((0, 0), 0.60, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(x.index, loc='upper left', bbox_to_anchor=(.8,1.05))
plt.title('QUALIFICATION')
plt.show()

# %%
deg = df[df['Degree']!='Data Not Entered']
plt.figure(figsize=(9,5))
x=sns.countplot(data = deg, x ='Degree')
for i in x.containers:
    x.bar_label(i)
plt.title("No of students as per Degree.")
plt.xticks(rotation=90)
plt.ylabel('No of students')
plt.show()

# %%
plt.figure(figsize=(10,5))
x=sns.countplot(data = deg, x ='Degree',hue='Gender')
for i in x.containers:
    x.bar_label(i)
plt.title("No of students as per relationship between Gender and Degree")
plt.xticks(rotation=90)
plt.ylabel('No of students')
plt.show()

# %%
date_label=df['Date']  # df['Date'] is a Timestamp column
def date_in_words(s):
  date=s.day
  if s.month==4:
    month='April '
  else:
    month='May '
  return month+str(date)

date_label=date_label.apply(date_in_words)

date_in_words = pd.DataFrame({'date': date_label.unique(),
                     'students': date_label.value_counts().values})

plt.figure(figsize=(10,5))
fig = sns.barplot(data = date_in_words, x = 'students', y = 'date')

for i in fig.containers:
    fig.bar_label(i)
plt.xlabel("No of students enrolled")
plt.ylabel("")
plt.title("No of students filled the form on the following date")
plt.show(fig)

# %%
x=df['City'].value_counts().head()
fig = go.Figure(go.Funnelarea(text = x.axes[0],
                              values = x.values,
                              showlegend=False))
fig.update_layout(width=600, height=600,
                  title="STUDENTS FROM TOP 5 CITIES",
                  title_x=0.5, title_y=0.9, font=dict(size=16))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="705e608f-2f8d-4700-8773-ba3618296855" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("705e608f-2f8d-4700-8773-ba3618296855")) {                    Plotly.newPlot(                        "705e608f-2f8d-4700-8773-ba3618296855",                        [{"showlegend":false,"text":["Chennai","Coimbatore","Salem","Vellore","Madurai"],"values":[25,12,9,7,5],"type":"funnelarea"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"c ...

# %%
lap=df['Have laptop?'].value_counts()

fig = go.Figure(go.Indicator(
    mode="gauge+number",
    value=lap[0],
    domain={'x': [0, 1], 'y': [0, 1]},
    title={'text': f"Students having laptop out of {df.shape[0]}"},
    gauge={'axis': {'range': [0, 100], 'dtick': 5},
           'threshold': {'line': {'color': "red", 'width': 4},
                         'thickness': 0.75, 'value': 97}}
))
fig.update_layout(width=600, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7100564d-7f5c-4e88-b593-bbcdada83b51" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7100564d-7f5c-4e88-b593-bbcdada83b51")) {                    Plotly.newPlot(                        "7100564d-7f5c-4e88-b593-bbcdada83b51",                        [{"domain":{"x":[0,1],"y":[0,1]},"gauge":{"axis":{"dtick":5,"range":[0,100]},"threshold":{"line":{"color":"red","width":4},"thickness":0.75,"value":97}},"mode":"gauge+number","title":{"text":"Students having laptop out of 97"},"value":84,"type":"indicator"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"m ...

# %%
degree_5=df['Degree'].value_counts().head()

fig = go.Figure(go.Funnel(y = degree_5.axes[0], x = degree_5.values))
fig.update_layout(width=700,height=500,
                  title="No of Students enrolled from Degree (top-5)",
                  title_x=0.5, title_y=0.9)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="916731f2-a39e-4ca5-92b0-4a97968effed" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("916731f2-a39e-4ca5-92b0-4a97968effed")) {                    Plotly.newPlot(                        "916731f2-a39e-4ca5-92b0-4a97968effed",                        [{"x":[37,15,11,10,5],"y":["B.E","BCA","B.Sc","B.Com","B.Tech"],"type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...

# %%
x=df['Confidence Rating'].value_counts().tail().head(4)

plt.pie(x, labels=x.values, autopct='%0.1f%%',
        colors=['#90EE90','#87CEEB','#EDB1B1','#CACACA'],
        pctdistance=0.80)

centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(x.index, loc='upper left', bbox_to_anchor=(0.9, 1))
plt.title('No of people got CONFIDENCE RATING\n(before selection)')
plt.show()

# %% [markdown]
# #SELECTED STUDENTS VISUALISATION#

# %%
df_selected = df[df.Status=='Selected']

# %%
selected=df_selected.shape[0]
unselected=df.shape[0]-df_selected.shape[0]
x=[selected,unselected]
plt.pie(x, labels=x, autopct='%0.1f%%',
        colors=['#57C428','#FF4715'])
plt.legend(['Selected','Unselected'], loc='upper left', bbox_to_anchor=(1, 1.02))
plt.title('No of people got SELECTED')
plt.show()

# %%
plt.figure(figsize=(4,5))
x=sns.countplot(df_selected,x='Gender')
for i in x.containers:
  x.bar_label(i)
plt.title("Gender count (Selected)")
plt.show()

# %%
x=df_selected['Domain'].value_counts()
plt.figure(figsize=(7,7))
plt.pie(x, labels=x.values, autopct='%0.1f%%',
        colors= ['#87CEEB','#EDB1B1','#E74C3C',
                 '#3498DB','#2ECC71','#CACACA','#F1C40F'])
plt.legend(x.index, loc='upper left', bbox_to_anchor=(.8, 1.05))
plt.title('DOMAIN OF SELECTED PEOPLE')
plt.show()

# %%
deg=df_selected[df_selected['Degree']!='Data Not Entered']
plt.figure(figsize=(7,5))
x=sns.countplot(data = deg, x ='Degree')
for i in x.containers:
    x.bar_label(i)
plt.title("No of selected students as per Degree.")
plt.xticks(rotation=90)
plt.ylabel('No of students')
plt.show()

# %%
x=df_selected['Qualification'].value_counts()
plt.pie(x, labels=x.values, autopct='%0.1f%%',
        colors=['#90EE90','#87CEEB'],
        pctdistance=0.70)

centre_circle = plt.Circle((0, 0), 0.50, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(x.index, loc='upper left', bbox_to_anchor=(0.9,0.9))
plt.title('QUALIFICATION  OF SELECTED STUDENTS')
plt.show()

# %%
x=df_selected['City'].value_counts()
fig = go.Figure(go.Funnelarea(text = x.axes[0],
                              values = x.values,
                              showlegend=False))
fig.update_layout(width=700,height=700,
                  title="CITIES OF SELECTED STUDENTS",
                  title_x=0.5, title_y=0.9,
                  font=dict(size=14))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="21e9cfae-6098-4ff2-906b-a37df2a1decc" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21e9cfae-6098-4ff2-906b-a37df2a1decc")) {                    Plotly.newPlot(                        "21e9cfae-6098-4ff2-906b-a37df2a1decc",                        [{"showlegend":false,"text":["Chennai","Madurai","Salem","Paramakudi","Coimbatore","Tiruppur"],"values":[4,3,3,1,1,1],"type":"funnelarea"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl ...

# %%
plt.figure(figsize=(6,5))
x=sns.countplot(df_selected,x='YOP')
for i in x.containers:
  x.bar_label(i)
plt.title("Year of passing of Selected Students")
plt.show()
